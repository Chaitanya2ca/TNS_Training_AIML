# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitanya2ca/TNS_Training_AIML/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Calculate Simple Intrest
P=int(input("Enter Principal Amount:"))
T=float(input("Enter Time in Years:"))
R=float(input("Enter Rate of Intrest:"))
SI=P*R*T/100           #Formulae
print("Simple Intrest:",SI)
# Out:
# Enter Principal Amount:100000
# Enter Time in Years:2
# Enter Rate of Intrest:1.5
# Simple Intrest: 3000.0

# %%
#Calculate Total and Percentage of 5 Subjects
S1=int(input("Enter marks of Telugu:"))
S2=int(input("Enter marks of Hindi:"))
S3=int(input("Enter marks of English:"))
S4=int(input("Enter marks of Maths:"))
S5=int(input("Enter marks of Science:"))
MarksObtained=S1+S2+S3+S4+S59
TotalMarks=500
Percentage=MarksObtained/TotalMarks*100 #Formulae
print("Total Marks Obtained:",TotalMarks)
print("Percentage:",Percentage)
# Out:
# Enter marks of Telugu:90
# Enter marks of Hindi:85
# Enter marks of English:88
# Enter marks of Maths:92
# Enter marks of Science:94
# Total Marks Obtained: 500
# Percentage: 89.8

# %%
#Find Quotient and Remainder using Arthmetic Operators
a=int(input("Enter First Number:"))
b=int(input("Enter Second Number:"))
print("Quotient:",a/b)
print("Remainder:",a%b)
# Out:
# Enter First Number:4
# Enter Second Number:2
# Quotient: 2.0
# Remainder: 0

# %%
#Find Area of Circle using Radius as Input
r=int(input("Enter Radius:"))
Area=3.14*r*r     #Formulae
print("Area of Circle:",Area)
# Out:
# Enter Radius:22
# Area of Circle: 1519.76

# %%
#Swap Two Variables without using Temporary Variables
a=int(input("Enter First Number:"))
b=int(input("Enter Second Number:"))
a=a+b
b=a-b
a=a-b
print("After Swapping:")
print("First Number:",a)
print("Second Number:",b)
# Out:
# Enter First Number:22
# Enter Second Number:10
# After Swapping:
# First Number: 10
# Second Number: 22
